# %%
import nltk
nltk.download('punkt')
from nltk.stem import PorterStemmer, SnowballStemmer, LancasterStemmer, RegexpStemmer

# Sample corpus
corpus = [
"The quick brown foxes jumped over the lazy dogs.",
"He was playing with the cats in the garden.",
"The books on the shelf were dusty.",
"She loves reading interesting novels.",
"The company's products are top-notch.",
"They quickly ran to catch the last train.",
"I bought several delicious apples from the market.",
"The weather today is quite unpredictable.",
"I need to study for my upcoming exams.",
"The children were happily playing in the park.",
"In the vast forest, the birds chirped loudly.",
"The chef prepared a delicious meal for us.",
"My computer crashed while I was working.",
"The mountains are covered with snow in winter.",
"She enjoys listening to classical music.",
"The museum has an impressive collection of art.",
"The river flows peacefully through the valley.",
"The old house creaked in the night.",
"They celebrated their anniversary with a big party.",
"The detective solved the mysterious case.",
"The students eagerly awaited their exam results.",
"The sunsets on the beach are breathtaking.",
"She wore a beautiful dress to the party.",
"The city is bustling with activity.",
"The athletes trained hard for the competition.",
"The scientist made a groundbreaking discovery.",
"I visited the historic castle on my vacation.",
"The garden is full of colorful flowers.",
"He gave an inspiring speech at the conference.",
"The train station was crowded with travelers.",
"The old tree provided shade in the scorching heat.",
"The beach was crowded with sunbathers.",
"The orchestra played a beautiful symphony.",
"The students formed a study group for the exam.",
"The car engine roared to life.",
"The rain fell steadily throughout the night.",
"The dog barked loudly at the mailman.",
"The stars shone brightly in the clear night sky.",
"The chef used fresh ingredients in the recipe.",
"The cat purred contentedly on the windowsill.",
"The construction workers were busy on the site.",
"The flowers bloomed in vibrant colors.",
"The politician delivered a passionate speech.",
"The ocean waves crashed against the shore.",
"The artist painted a stunning landscape.",
"The laughter of children filled the playground.",
"The clock ticked loudly in the quiet room.",
"The scientist conducted experiments in the lab.",
"The coffee shop was a cozy place to relax.",
"The hikers enjoyed the beautiful scenery.",
"The singer had a powerful and melodious voice.",
"The bicycle race covered a long distance.",
"The company announced a new product launch.",
"The spider spun a delicate web.",
"The fireworks lit up the night sky.",
"The sunrises in the mountains were breathtaking.",
"The astronauts explored the depths of space.",
"The novelist wrote a gripping thriller.",
"The ship sailed across the open sea.",
"The teacher explained the complex topic.",
"The thunderstorm rumbled in the distance.",
"The river meandered through the countryside.",
"The mechanic repaired the car's engine.",
"The children built sandcastles on the beach.",
"The basketball team won the championship.",
"The dancers moved gracefully on the stage.",
"The bakery sold fresh bread and pastries.",
"The photographer captured stunning landscapes.",
"The city skyline was illuminated at night.",
"The archaeologists discovered ancient artifacts.",
"The rainbows appeared after the rain shower.",
"The lawyer argued the case in court.",
"The birds chirped merrily in the morning.",
"The nurse cared for the patients with kindness.",
"The scientist made a breakthrough in research.",
"The gardeners tended to the blooming flowers.",
"The snowfall covered the town in white.",
"The actor performed brilliantly on stage.",
"The students organized a charity fundraiser.",
"The waves crashed against the rocky shore.",
"The chef prepared a gourmet meal.",
"The athletes competed in the Olympic Games.",
"The movie director filmed a thrilling scene.",
"The passengers boarded the train.",
"The astronauts conducted experiments in space.",
"The author wrote a best-selling novel.",
"The wind whispered through the trees.",
"The children played games in the backyard.",
"The mechanic fixed the broken car.",
"The musician played a soulful melody.",
"The scientists analyzed the data carefully.",
"The beachcombers searched for seashells.",
"The artist exhibited paintings in the gallery.",
"The teacher inspired her students.",
"The firefighters extinguished the blazing fire.",
"The tourists explored the ancient ruins.",
"The software engineer coded a new program.",
"The marathon runners raced through the city.",
"The family gathered for a holiday dinner.",
"The astronaut floated in zero gravity."

]

# Initialize stemmers
porter = PorterStemmer()
snowball = SnowballStemmer("english")
lancaster = LancasterStemmer()
# Define custom regular expression rules for Regexp Stemmer
custom_pattern = r'ing$|ed$|es$|s$|ly$'
regexp = RegexpStemmer(custom_pattern)

# Apply and print stemming for each line in the corpus
for line in corpus:
    words = nltk.word_tokenize(line.lower())  # Tokenize and convert to lowercase
    porter_stemmed = [porter.stem(word) for word in words]
    snowball_stemmed = [snowball.stem(word) for word in words]
    lancaster_stemmed = [lancaster.stem(word) for word in words]
    regexp_stemmed = [regexp.stem(word) for word in words]

    print("Original: ", line)
    print("Porter: ", " ".join(porter_stemmed))
    print("Snowball: ", " ".join(snowball_stemmed))
    print("Lancaster: ", " ".join(lancaster_stemmed))
    print("Regexp: ", " ".join(regexp_stemmed))
    print()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sargu\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# Original:  The quick brown foxes jumped over the lazy dogs.
# Porter:  the quick brown fox jump over the lazi dog .
# Snowball:  the quick brown fox jump over the lazi dog .
# Lancaster:  the quick brown fox jump ov the lazy dog .
# Regexp:  the quick brown fox jump over the lazy dog .
#
# Original:  He was playing with the cats in the garden.
# Porter:  he wa play with the cat in the garden .
# Snowball:  he was play with the cat in the garden .
# Lancaster:  he was play with the cat in the gard .
# Regexp:  he wa play with the cat in the garden .
#
# Original:  The books on the shelf were dusty.
# Porter:  the book on the shelf were dusti .
# Snowball:  the book on the shelf were dusti .
# Lancaster:  the book on the shelf wer dusty .
# Regexp:  the book on the shelf were dusty .
#
# Original:  She loves reading interesting novels.
# Porter:  she love read interest novel .
# Snowball:  she love read interest novel .
# Lancaster:  she lov read interest novel .
# Regexp:  she lov read interest novel .
#
# Original:  The company's products are top-notch.
# Porter:  the compani 's product are top-notch .
# Snowball:  the compani 's product are top-notch .
# Lancaster:  the company 's produc ar top-notch .
# Regexp:  the company ' product are top-notch .
#
# Original:  They quickly ran to catch the last train.
# Porter:  they quickli ran to catch the last train .
# Snowball:  they quick ran to catch the last train .
# Lancaster:  they quick ran to catch the last train .
# Regexp:  they quick ran to catch the last train .
#
# Original:  I bought several delicious apples from the market.
# Porter:  i bought sever delici appl from the market .
# Snowball:  i bought sever delici appl from the market .
# Lancaster:  i bought sev delicy appl from the market .
# Regexp:  i bought several deliciou appl from the market .
#
# Original:  The weather today is quite unpredictable.
# Porter:  the weather today is quit unpredict .
# Snowball:  the weather today is quit unpredict .
# Lancaster:  the weath today is quit unpredict .
# Regexp:  the weather today i quite unpredictable .
#
# Original:  I need to study for my upcoming exams.
# Porter:  i need to studi for my upcom exam .
# Snowball:  i need to studi for my upcom exam .
# Lancaster:  i nee to study for my upcom exam .
# Regexp:  i ne to study for my upcom exam .
#
# Original:  The children were happily playing in the park.
# Porter:  the children were happili play in the park .
# Snowball:  the children were happili play in the park .
# Lancaster:  the childr wer happy play in the park .
# Regexp:  the children were happi play in the park .
#
# Original:  In the vast forest, the birds chirped loudly.
# Porter:  in the vast forest , the bird chirp loudli .
# Snowball:  in the vast forest , the bird chirp loud .
# Lancaster:  in the vast forest , the bird chirp loud .
# Regexp:  in the vast forest , the bird chirp loud .
#
# Original:  The chef prepared a delicious meal for us.
# Porter:  the chef prepar a delici meal for us .
# Snowball:  the chef prepar a delici meal for us .
# Lancaster:  the chef prep a delicy meal for us .
# Regexp:  the chef prepar a deliciou meal for u .
#
# Original:  My computer crashed while I was working.
# Porter:  my comput crash while i wa work .
# Snowball:  my comput crash while i was work .
# Lancaster:  my comput crash whil i was work .
# Regexp:  my computer crash while i wa work .
#
# Original:  The mountains are covered with snow in winter.
# Porter:  the mountain are cover with snow in winter .
# Snowball:  the mountain are cover with snow in winter .
# Lancaster:  the mountain ar cov with snow in wint .
# Regexp:  the mountain are cover with snow in winter .
#
# Original:  She enjoys listening to classical music.
# Porter:  she enjoy listen to classic music .
# Snowball:  she enjoy listen to classic music .
# Lancaster:  she enjoy list to class mus .
# Regexp:  she enjoy listen to classical music .
#
# Original:  The museum has an impressive collection of art.
# Porter:  the museum ha an impress collect of art .
# Snowball:  the museum has an impress collect of art .
# Lancaster:  the muse has an impress collect of art .
# Regexp:  the museum ha an impressive collection of art .
#
# Original:  The river flows peacefully through the valley.
# Porter:  the river flow peac through the valley .
# Snowball:  the river flow peac through the valley .
# Lancaster:  the riv flow peac through the valley .
# Regexp:  the river flow peaceful through the valley .
#
# Original:  The old house creaked in the night.
# Porter:  the old hous creak in the night .
# Snowball:  the old hous creak in the night .
# Lancaster:  the old hous creak in the night .
# Regexp:  the old house creak in the night .
#
# Original:  They celebrated their anniversary with a big party.
# Porter:  they celebr their anniversari with a big parti .
# Snowball:  they celebr their anniversari with a big parti .
# Lancaster:  they celebr their annivers with a big party .
# Regexp:  they celebrat their anniversary with a big party .
#
# Original:  The detective solved the mysterious case.
# Porter:  the detect solv the mysteri case .
# Snowball:  the detect solv the mysteri case .
# Lancaster:  the detect solv the mystery cas .
# Regexp:  the detective solv the mysteriou case .
#
# Original:  The students eagerly awaited their exam results.
# Porter:  the student eagerli await their exam result .
# Snowball:  the student eager await their exam result .
# Lancaster:  the stud eag await their exam result .
# Regexp:  the student eager await their exam result .
#
# Original:  The sunsets on the beach are breathtaking.
# Porter:  the sunset on the beach are breathtak .
# Snowball:  the sunset on the beach are breathtak .
# Lancaster:  the sunset on the beach ar breathtak .
# Regexp:  the sunset on the beach are breathtak .
#
# Original:  She wore a beautiful dress to the party.
# Porter:  she wore a beauti dress to the parti .
# Snowball:  she wore a beauti dress to the parti .
# Lancaster:  she wor a beauty dress to the party .
# Regexp:  she wore a beautiful dres to the party .
#
# Original:  The city is bustling with activity.
# Porter:  the citi is bustl with activ .
# Snowball:  the citi is bustl with activ .
# Lancaster:  the city is bustl with act .
# Regexp:  the city i bustl with activity .
#
# Original:  The athletes trained hard for the competition.
# Porter:  the athlet train hard for the competit .
# Snowball:  the athlet train hard for the competit .
# Lancaster:  the athlet train hard for the competit .
# Regexp:  the athlet train hard for the competition .
#
# Original:  The scientist made a groundbreaking discovery.
# Porter:  the scientist made a groundbreak discoveri .
# Snowball:  the scientist made a groundbreak discoveri .
# Lancaster:  the sci mad a groundbreak discovery .
# Regexp:  the scientist made a groundbreak discovery .
#
# Original:  I visited the historic castle on my vacation.
# Porter:  i visit the histor castl on my vacat .
# Snowball:  i visit the histor castl on my vacat .
# Lancaster:  i visit the hist castl on my vac .
# Regexp:  i visit the historic castle on my vacation .
#
# Original:  The garden is full of colorful flowers.
# Porter:  the garden is full of color flower .
# Snowball:  the garden is full of color flower .
# Lancaster:  the gard is ful of col flow .
# Regexp:  the garden i full of colorful flower .
#
# Original:  He gave an inspiring speech at the conference.
# Porter:  he gave an inspir speech at the confer .
# Snowball:  he gave an inspir speech at the confer .
# Lancaster:  he gav an inspir speech at the conf .
# Regexp:  he gave an inspir speech at the conference .
#
# Original:  The train station was crowded with travelers.
# Porter:  the train station wa crowd with travel .
# Snowball:  the train station was crowd with travel .
# Lancaster:  the train stat was crowd with travel .
# Regexp:  the train station wa crowd with traveler .
#
# Original:  The old tree provided shade in the scorching heat.
# Porter:  the old tree provid shade in the scorch heat .
# Snowball:  the old tree provid shade in the scorch heat .
# Lancaster:  the old tre provid shad in the scorch heat .
# Regexp:  the old tree provid shade in the scorch heat .
#
# Original:  The beach was crowded with sunbathers.
# Porter:  the beach wa crowd with sunbath .
# Snowball:  the beach was crowd with sunbath .
# Lancaster:  the beach was crowd with sunbath .
# Regexp:  the beach wa crowd with sunbather .
#
# Original:  The orchestra played a beautiful symphony.
# Porter:  the orchestra play a beauti symphoni .
# Snowball:  the orchestra play a beauti symphoni .
# Lancaster:  the orchestr play a beauty symphony .
# Regexp:  the orchestra play a beautiful symphony .
#
# Original:  The students formed a study group for the exam.
# Porter:  the student form a studi group for the exam .
# Snowball:  the student form a studi group for the exam .
# Lancaster:  the stud form a study group for the exam .
# Regexp:  the student form a study group for the exam .
#
# Original:  The car engine roared to life.
# Porter:  the car engin roar to life .
# Snowball:  the car engin roar to life .
# Lancaster:  the car engin roar to lif .
# Regexp:  the car engine roar to life .
#
# Original:  The rain fell steadily throughout the night.
# Porter:  the rain fell steadili throughout the night .
# Snowball:  the rain fell steadili throughout the night .
# Lancaster:  the rain fel steady throughout the night .
# Regexp:  the rain fell steadi throughout the night .
#
# Original:  The dog barked loudly at the mailman.
# Porter:  the dog bark loudli at the mailman .
# Snowball:  the dog bark loud at the mailman .
# Lancaster:  the dog bark loud at the mailm .
# Regexp:  the dog bark loud at the mailman .
#
# Original:  The stars shone brightly in the clear night sky.
# Porter:  the star shone brightli in the clear night sky .
# Snowball:  the star shone bright in the clear night sky .
# Lancaster:  the star shon bright in the clear night sky .
# Regexp:  the star shone bright in the clear night sky .
#
# Original:  The chef used fresh ingredients in the recipe.
# Porter:  the chef use fresh ingredi in the recip .
# Snowball:  the chef use fresh ingredi in the recip .
# Lancaster:  the chef us fresh ingredy in the recip .
# Regexp:  the chef us fresh ingredient in the recipe .
#
# Original:  The cat purred contentedly on the windowsill.
# Porter:  the cat pur contentedli on the windowsil .
# Snowball:  the cat pur content on the windowsil .
# Lancaster:  the cat pur cont on the windowsil .
# Regexp:  the cat purr contented on the windowsill .
#
# Original:  The construction workers were busy on the site.
# Porter:  the construct worker were busi on the site .
# Snowball:  the construct worker were busi on the site .
# Lancaster:  the construct work wer busy on the sit .
# Regexp:  the construction worker were busy on the site .
#
# Original:  The flowers bloomed in vibrant colors.
# Porter:  the flower bloom in vibrant color .
# Snowball:  the flower bloom in vibrant color .
# Lancaster:  the flow bloom in vibr col .
# Regexp:  the flower bloom in vibrant color .
#
# Original:  The politician delivered a passionate speech.
# Porter:  the politician deliv a passion speech .
# Snowball:  the politician deliv a passion speech .
# Lancaster:  the polit del a pass speech .
# Regexp:  the politician deliver a passionate speech .
#
# Original:  The ocean waves crashed against the shore.
# Porter:  the ocean wave crash against the shore .
# Snowball:  the ocean wave crash against the shore .
# Lancaster:  the oc wav crash against the shor .
# Regexp:  the ocean wav crash against the shore .
#
# Original:  The artist painted a stunning landscape.
# Porter:  the artist paint a stun landscap .
# Snowball:  the artist paint a stun landscap .
# Lancaster:  the art paint a stun landscap .
# Regexp:  the artist paint a stunn landscape .
#
# Original:  The laughter of children filled the playground.
# Porter:  the laughter of children fill the playground .
# Snowball:  the laughter of children fill the playground .
# Lancaster:  the laught of childr fil the playground .
# Regexp:  the laughter of children fill the playground .
#
# Original:  The clock ticked loudly in the quiet room.
# Porter:  the clock tick loudli in the quiet room .
# Snowball:  the clock tick loud in the quiet room .
# Lancaster:  the clock tick loud in the quiet room .
# Regexp:  the clock tick loud in the quiet room .
#
# Original:  The scientist conducted experiments in the lab.
# Porter:  the scientist conduct experi in the lab .
# Snowball:  the scientist conduct experi in the lab .
# Lancaster:  the sci conduc expery in the lab .
# Regexp:  the scientist conduct experiment in the lab .
#
# Original:  The coffee shop was a cozy place to relax.
# Porter:  the coffe shop wa a cozi place to relax .
# Snowball:  the coffe shop was a cozi place to relax .
# Lancaster:  the coff shop was a cozy plac to relax .
# Regexp:  the coffee shop wa a cozy place to relax .
#
# Original:  The hikers enjoyed the beautiful scenery.
# Porter:  the hiker enjoy the beauti sceneri .
# Snowball:  the hiker enjoy the beauti sceneri .
# Lancaster:  the hik enjoy the beauty scenery .
# Regexp:  the hiker enjoy the beautiful scenery .
#
# Original:  The singer had a powerful and melodious voice.
# Porter:  the singer had a power and melodi voic .
# Snowball:  the singer had a power and melodi voic .
# Lancaster:  the sing had a pow and melody voic .
# Regexp:  the singer had a powerful and melodiou voice .
#
# Original:  The bicycle race covered a long distance.
# Porter:  the bicycl race cover a long distanc .
# Snowball:  the bicycl race cover a long distanc .
# Lancaster:  the bicyc rac cov a long dist .
# Regexp:  the bicycle race cover a long distance .
#
# Original:  The company announced a new product launch.
# Porter:  the compani announc a new product launch .
# Snowball:  the compani announc a new product launch .
# Lancaster:  the company annount a new produc launch .
# Regexp:  the company announc a new product launch .
#
# Original:  The spider spun a delicate web.
# Porter:  the spider spun a delic web .
# Snowball:  the spider spun a delic web .
# Lancaster:  the spid spun a del web .
# Regexp:  the spider spun a delicate web .
#
# Original:  The fireworks lit up the night sky.
# Porter:  the firework lit up the night sky .
# Snowball:  the firework lit up the night sky .
# Lancaster:  the firework lit up the night sky .
# Regexp:  the firework lit up the night sky .
#
# Original:  The sunrises in the mountains were breathtaking.
# Porter:  the sunris in the mountain were breathtak .
# Snowball:  the sunris in the mountain were breathtak .
# Lancaster:  the sunr in the mountain wer breathtak .
# Regexp:  the sunris in the mountain were breathtak .
#
# Original:  The astronauts explored the depths of space.
# Porter:  the astronaut explor the depth of space .
# Snowball:  the astronaut explor the depth of space .
# Lancaster:  the astronaut expl the depth of spac .
# Regexp:  the astronaut explor the depth of space .
#
# Original:  The novelist wrote a gripping thriller.
# Porter:  the novelist wrote a grip thriller .
# Snowball:  the novelist wrote a grip thriller .
# Lancaster:  the novel wrot a grip thriller .
# Regexp:  the novelist wrote a gripp thriller .
#
# Original:  The ship sailed across the open sea.
# Porter:  the ship sail across the open sea .
# Snowball:  the ship sail across the open sea .
# Lancaster:  the ship sail across the op sea .
# Regexp:  the ship sail acros the open sea .
#
# Original:  The teacher explained the complex topic.
# Porter:  the teacher explain the complex topic .
# Snowball:  the teacher explain the complex topic .
# Lancaster:  the teach explain the complex top .
# Regexp:  the teacher explain the complex topic .
#
# Original:  The thunderstorm rumbled in the distance.
# Porter:  the thunderstorm rumbl in the distanc .
# Snowball:  the thunderstorm rumbl in the distanc .
# Lancaster:  the thunderstorm rumbl in the dist .
# Regexp:  the thunderstorm rumbl in the distance .
#
# Original:  The river meandered through the countryside.
# Porter:  the river meander through the countrysid .
# Snowball:  the river meander through the countrysid .
# Lancaster:  the riv meand through the countrysid .
# Regexp:  the river meander through the countryside .
#
# Original:  The mechanic repaired the car's engine.
# Porter:  the mechan repair the car 's engin .
# Snowball:  the mechan repair the car 's engin .
# Lancaster:  the mech repair the car 's engin .
# Regexp:  the mechanic repair the car ' engine .
#
# Original:  The children built sandcastles on the beach.
# Porter:  the children built sandcastl on the beach .
# Snowball:  the children built sandcastl on the beach .
# Lancaster:  the childr built sandcastl on the beach .
# Regexp:  the children built sandcastl on the beach .
#
# Original:  The basketball team won the championship.
# Porter:  the basketbal team won the championship .
# Snowball:  the basketbal team won the championship .
# Lancaster:  the basketbal team won the champ .
# Regexp:  the basketball team won the championship .
#
# Original:  The dancers moved gracefully on the stage.
# Porter:  the dancer move grace on the stage .
# Snowball:  the dancer move grace on the stage .
# Lancaster:  the dant mov grac on the stag .
# Regexp:  the dancer mov graceful on the stage .
#
# Original:  The bakery sold fresh bread and pastries.
# Porter:  the bakeri sold fresh bread and pastri .
# Snowball:  the bakeri sold fresh bread and pastri .
# Lancaster:  the bakery sold fresh bread and pastry .
# Regexp:  the bakery sold fresh bread and pastri .
#
# Original:  The photographer captured stunning landscapes.
# Porter:  the photograph captur stun landscap .
# Snowball:  the photograph captur stun landscap .
# Lancaster:  the photograph capt stun landscap .
# Regexp:  the photographer captur stunn landscap .
#
# Original:  The city skyline was illuminated at night.
# Porter:  the citi skylin wa illumin at night .
# Snowball:  the citi skylin was illumin at night .
# Lancaster:  the city skylin was illumin at night .
# Regexp:  the city skyline wa illuminat at night .
#
# Original:  The archaeologists discovered ancient artifacts.
# Porter:  the archaeologist discov ancient artifact .
# Snowball:  the archaeologist discov ancient artifact .
# Lancaster:  the archaeolog discov ant artifact .
# Regexp:  the archaeologist discover ancient artifact .
#
# Original:  The rainbows appeared after the rain shower.
# Porter:  the rainbow appear after the rain shower .
# Snowball:  the rainbow appear after the rain shower .
# Lancaster:  the rainbow appear aft the rain show .
# Regexp:  the rainbow appear after the rain shower .
#
# Original:  The lawyer argued the case in court.
# Porter:  the lawyer argu the case in court .
# Snowball:  the lawyer argu the case in court .
# Lancaster:  the lawy argu the cas in court .
# Regexp:  the lawyer argu the case in court .
#
# Original:  The birds chirped merrily in the morning.
# Porter:  the bird chirp merrili in the morn .
# Snowball:  the bird chirp merrili in the morn .
# Lancaster:  the bird chirp merry in the morn .
# Regexp:  the bird chirp merri in the morn .
#
# Original:  The nurse cared for the patients with kindness.
# Porter:  the nurs care for the patient with kind .
# Snowball:  the nurs care for the patient with kind .
# Lancaster:  the nurs car for the paty with kind .
# Regexp:  the nurse car for the patient with kindnes .
#
# Original:  The scientist made a breakthrough in research.
# Porter:  the scientist made a breakthrough in research .
# Snowball:  the scientist made a breakthrough in research .
# Lancaster:  the sci mad a breakthrough in research .
# Regexp:  the scientist made a breakthrough in research .
#
# Original:  The gardeners tended to the blooming flowers.
# Porter:  the garden tend to the bloom flower .
# Snowball:  the garden tend to the bloom flower .
# Lancaster:  the gard tend to the bloom flow .
# Regexp:  the gardener tend to the bloom flower .
#
# Original:  The snowfall covered the town in white.
# Porter:  the snowfal cover the town in white .
# Snowball:  the snowfal cover the town in white .
# Lancaster:  the snowfal cov the town in whit .
# Regexp:  the snowfall cover the town in white .
#
# Original:  The actor performed brilliantly on stage.
# Porter:  the actor perform brilliantli on stage .
# Snowball:  the actor perform brilliant on stage .
# Lancaster:  the act perform bril on stag .
# Regexp:  the actor perform brilliant on stage .
#
# Original:  The students organized a charity fundraiser.
# Porter:  the student organ a chariti fundrais .
# Snowball:  the student organ a chariti fundrais .
# Lancaster:  the stud org a char fundra .
# Regexp:  the student organiz a charity fundraiser .
#
# Original:  The waves crashed against the rocky shore.
# Porter:  the wave crash against the rocki shore .
# Snowball:  the wave crash against the rocki shore .
# Lancaster:  the wav crash against the rocky shor .
# Regexp:  the wav crash against the rocky shore .
#
# Original:  The chef prepared a gourmet meal.
# Porter:  the chef prepar a gourmet meal .
# Snowball:  the chef prepar a gourmet meal .
# Lancaster:  the chef prep a gourmet meal .
# Regexp:  the chef prepar a gourmet meal .
#
# Original:  The athletes competed in the Olympic Games.
# Porter:  the athlet compet in the olymp game .
# Snowball:  the athlet compet in the olymp game .
# Lancaster:  the athlet compet in the olymp gam .
# Regexp:  the athlet compet in the olympic gam .
#
# Original:  The movie director filmed a thrilling scene.
# Porter:  the movi director film a thrill scene .
# Snowball:  the movi director film a thrill scene .
# Lancaster:  the movy direct film a thrilling scen .
# Regexp:  the movie director film a thrill scene .
#
# Original:  The passengers boarded the train.
# Porter:  the passeng board the train .
# Snowball:  the passeng board the train .
# Lancaster:  the passeng board the train .
# Regexp:  the passenger board the train .
#
# Original:  The astronauts conducted experiments in space.
# Porter:  the astronaut conduct experi in space .
# Snowball:  the astronaut conduct experi in space .
# Lancaster:  the astronaut conduc expery in spac .
# Regexp:  the astronaut conduct experiment in space .
#
# Original:  The author wrote a best-selling novel.
# Porter:  the author wrote a best-sel novel .
# Snowball:  the author wrote a best-sel novel .
# Lancaster:  the auth wrot a best-selling novel .
# Regexp:  the author wrote a best-sell novel .
#
# Original:  The wind whispered through the trees.
# Porter:  the wind whisper through the tree .
# Snowball:  the wind whisper through the tree .
# Lancaster:  the wind whisp through the tre .
# Regexp:  the wind whisper through the tre .
#
# Original:  The children played games in the backyard.
# Porter:  the children play game in the backyard .
# Snowball:  the children play game in the backyard .
# Lancaster:  the childr play gam in the backyard .
# Regexp:  the children play gam in the backyard .
#
# Original:  The mechanic fixed the broken car.
# Porter:  the mechan fix the broken car .
# Snowball:  the mechan fix the broken car .
# Lancaster:  the mech fix the brok car .
# Regexp:  the mechanic fix the broken car .
#
# Original:  The musician played a soulful melody.
# Porter:  the musician play a soul melodi .
# Snowball:  the musician play a soul melodi .
# Lancaster:  the mus play a soul melody .
# Regexp:  the musician play a soulful melody .
#
# Original:  The scientists analyzed the data carefully.
# Porter:  the scientist analyz the data care .
# Snowball:  the scientist analyz the data care .
# Lancaster:  the sci analys the dat car .
# Regexp:  the scientist analyz the data careful .
#
# Original:  The beachcombers searched for seashells.
# Porter:  the beachcomb search for seashel .
# Snowball:  the beachcomb search for seashel .
# Lancaster:  the beachcomb search for seashel .
# Regexp:  the beachcomber search for seashell .
#
# Original:  The artist exhibited paintings in the gallery.
# Porter:  the artist exhibit paint in the galleri .
# Snowball:  the artist exhibit paint in the galleri .
# Lancaster:  the art exhibit paint in the gallery .
# Regexp:  the artist exhibit painting in the gallery .
#
# Original:  The teacher inspired her students.
# Porter:  the teacher inspir her student .
# Snowball:  the teacher inspir her student .
# Lancaster:  the teach inspir her stud .
# Regexp:  the teacher inspir her student .
#
# Original:  The firefighters extinguished the blazing fire.
# Porter:  the firefight extinguish the blaze fire .
# Snowball:  the firefight extinguish the blaze fire .
# Lancaster:  the firefight extinct the blaz fir .
# Regexp:  the firefighter extinguish the blaz fire .
#
# Original:  The tourists explored the ancient ruins.
# Porter:  the tourist explor the ancient ruin .
# Snowball:  the tourist explor the ancient ruin .
# Lancaster:  the tour expl the ant ruin .
# Regexp:  the tourist explor the ancient ruin .
#
# Original:  The software engineer coded a new program.
# Porter:  the softwar engin code a new program .
# Snowball:  the softwar engin code a new program .
# Lancaster:  the softw engin cod a new program .
# Regexp:  the software engineer cod a new program .
#
# Original:  The marathon runners raced through the city.
# Porter:  the marathon runner race through the citi .
# Snowball:  the marathon runner race through the citi .
# Lancaster:  the marathon run rac through the city .
# Regexp:  the marathon runner rac through the city .
#
# Original:  The family gathered for a holiday dinner.
# Porter:  the famili gather for a holiday dinner .
# Snowball:  the famili gather for a holiday dinner .
# Lancaster:  the famy gath for a holiday din .
# Regexp:  the fami gather for a holiday dinner .
#
# Original:  The astronaut floated in zero gravity.
# Porter:  the astronaut float in zero graviti .
# Snowball:  the astronaut float in zero graviti .
# Lancaster:  the astronaut flo in zero grav .
# Regexp:  the astronaut float in zero gravity .
